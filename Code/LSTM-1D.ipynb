# %% [raw]
# A 1-D LSTM model:
# 1. Split the train/validation/test dataset. (can remove the validation set)
# 2. Re-arrange the input data: use year, SA3code and total population. For each column, it shows the the total pop for this area during the whole time range.
# 3. Fit the model and predict on the validation set.

# %% [markdown]
# # 1. Read data

# %%
import pandas as pd
import numpy as np
from collections import defaultdict

# %%
raw_data = pd.read_csv('above1000.csv')
sa3_num = len(raw_data['SA3 Code'].unique())

# %%
raw_data.head()
# Out:
#    Unnamed: 0  index  Year  S/T Code         S/T Name  GCCSA Code  \
# 0           0      1  1991       1.0  New South Wales        12.0
# 1           1      2  1991       1.0  New South Wales        12.0
# 2           2      3  1991       1.0  New South Wales        12.0
# 3           3      4  1991       1.0  New South Wales        12.0
# 4           4      5  1991       1.0  New South Wales        11.0
#
#        GCCSA Name  SA4 Code        SA4 Name  SA3 Code  ... f45-49  f50-54  \
# 0     Rest of NSW     101.0  Capital Region   10101.0  ...   1859    1591
# 1     Rest of NSW     101.0  Capital Region   10102.0  ...    991     745
# 2     Rest of NSW     101.0  Capital Region   10103.0  ...    504     413
# 3     Rest of NSW     101.0  Capital Region   10104.0  ...   1318    1370
# 4  Greater Sydney     102.0   Central Coast   10201.0  ...   3709    2884
#
#    f55-59  f60-64  f65-69  f70-74  f75-79  f80-84  f85+   Total
# 0    1412    1382    1252     967     799     493   353   61667
# 1     611     575     544     393     275     177   105   35281
# 2     328     320     258     237     152      97    59   18092
# 3    1651    2166    2075    1437     958     455   314   53440
# 4    2884    3567    4002    3573    2661    1565   965  135708
#
# [5 rows x 48 columns]

# %%
raw_data.columns
# Out:
# Index(['Unnamed: 0', 'index', 'Year', 'S/T Code', 'S/T Name', 'GCCSA Code',
#        'GCCSA Name', 'SA4 Code', 'SA4 Name', 'SA3 Code', 'SA3 Name', 'm0-4',
#        'm5-9', 'm10-14', 'm15-19', 'm20-24', 'm25-29', 'm30-34', 'm35-39',
#        'm40-44', 'm45-49', 'm50-54', 'm55-59', 'm60-64', 'm65-69', 'm70-74',
#        'm75-79', 'm80-84', 'm85+', 'f0-4', 'f5-9', 'f10-14', 'f15-19',
#        'f20-24', 'f25-29', 'f30-34', 'f35-39', 'f40-44', 'f45-49', 'f50-54',
#        'f55-59', 'f60-64', 'f65-69', 'f70-74', 'f75-79', 'f80-84', 'f85+',
#        'Total'],
#       dtype='object')

# %%
raw_data['m_total'] = raw_data.apply(lambda x: x['m0-4']+x['m5-9']+x['m10-14']+x['m15-19']+
                                               x['m20-24']+x['m25-29']+x['m30-34']+x['m35-39']+
                                               x['m40-44']+x['m45-49']+x['m50-54']+x['m55-59']+
                                               x['m60-64']+x['m65-69']+x['m70-74']+x['m75-79']+
                                               x['m80-84']+x['m85+'], axis=1)

# %%
raw_data['f_total'] = raw_data.apply(lambda x: x['f0-4']+x['f5-9']+x['f10-14']+x['f15-19']+
                                               x['f20-24']+x['f25-29']+x['f30-34']+x['f35-39']+
                                               x['f40-44']+x['f45-49']+x['f50-54']+x['f55-59']+
                                               x['f60-64']+x['f65-69']+x['f70-74']+x['f75-79']+
                                               x['f80-84']+x['f85+'], axis=1)

# %%
assert((raw_data['m_total']+raw_data['f_total'] == raw_data['Total']).all())

# %%
raw_data = raw_data[['Unnamed: 0', 'index', 'Year', 'SA3 Code', 'SA3 Name', 'm0-4',
       'm5-9', 'm10-14', 'm15-19', 'm20-24', 'm25-29', 'm30-34', 'm35-39',
       'm40-44', 'm45-49', 'm50-54', 'm55-59', 'm60-64', 'm65-69', 'm70-74',
       'm75-79', 'm80-84', 'm85+', 'f0-4', 'f5-9', 'f10-14', 'f15-19',
       'f20-24', 'f25-29', 'f30-34', 'f35-39', 'f40-44', 'f45-49', 'f50-54',
       'f55-59', 'f60-64', 'f65-69', 'f70-74', 'f75-79', 'f80-84', 'f85+',
       'm_total', 'f_total', 'Total']]

# %%
sa3_codes = raw_data['SA3 Code'].unique()

# %% [markdown]
# # 2. Split Train, Validation, Test set

# %%
train_data = raw_data[(raw_data['Year']>=1991) & (raw_data['Year']<=2001)]
val_data = raw_data[(raw_data['Year']>=2002) & (raw_data['Year']<=2005)]
# remove vali 10-10
test_data = raw_data[(raw_data['Year']>=2006) & (raw_data['Year']<=2011)]

# %%
# Create population dict for each region each year
population_per_year_dict = defaultdict(dict)
for sa3_code in sa3_codes:
    population_per_year_dict[sa3_code] = dict()
    for year in range(1991,2012):
        if(raw_data[(raw_data['Year']==year) & (raw_data['SA3 Code']==sa3_code)]['Total'].size>0):
            population_per_year_dict[sa3_code][year] = raw_data[(raw_data['Year']==year) & (raw_data['SA3 Code']==sa3_code)]['Total'].values[0]

# %%
pd.DataFrame(population_per_year_dict)
# Out:
#       10101.0  10102.0  10103.0  10104.0  10201.0  10202.0  10301.0  10302.0  \
# 1991    61667    35281    18092    53440   135708   104122    36738    60023
# 1992    61751    36409    18263    54889   139242   107654    37164    60213
# 1993    61706    37298    18362    55973   142034   110404    37509    60035
# 1994    61651    38190    18477    57127   144430   113134    37984    60038
# 1995    61602    38936    18568    57799   147027   115558    38442    59652
# 1996    61786    39563    18699    58677   149899   118851    38792    59383
# 1997    61968    40322    18589    59581   151861   121670    39149    59308
# 1998    62283    40883    18706    60599   153483   124406    39518    59248
# 1999    62576    42104    18826    61743   155897   127424    39979    59152
# 2000    62952    44026    18748    62960   158288   130656    40308    59010
# 2001    63370    45224    18810    64093   160596   134000    40816    58987
# 2002    63784    46614    19005    65063   161388   136142    41193    58617
# 2003    64245    48109    19084    65941   161458   137861    41414    58047
# 2004    64550    48820    19128    66787   161223   138776    41503    57398
# 2005    64891    49919    19205    67299   161462   139941    41809    56970
# 2006    65284    51118    19337    67708   161885   141166    42122    56674
# 2007    65807    52101    19413    68319   162975   143524    42448    56436
# 2008    66670    53273    19440    68762   165153   147185    43100    56218
# 2009    67745    54354    19501    69214   167081   149715    44095    56242
# 2010    68950    55410    19577    69989   168351   152010    44711    56397
# 2011    69775    56051    19595    70407   169018   153639    45176    56545
#
#       10303.0  10304.0  ...  70205.0  80101.0  80103.0  80105.0  80106.0  \
# 1991    43227    48674  ...    15699    89443     1815    39850    20955
# 1992    43364    49161  ...    16178    88685     1795    39696    20955
# 1993    43381    49512  ...    16642    87620     1789    39210    21156
# 1994    43409    49625  ...    17127    86181     1745    38961    21262
# 1995    43427    49588  ...    17555    85706     1652    38596    21481
# 1996    43392    49636  ...    18038    85987     1587    38617    21618
# 1997    43371    50036  ...    18231    85246     1561    38332    21911
# 1998    43345    50836  ...    18497    85049     1519    38033    21924
# 1999    43624    51464  ...    18703    85041     1474    37995    22101
# 2000    43593    51902  ...    18860    85577     1441    38242    22157
# 2001    43738    52288  ...    18972    86182     1399    38610    22300
# 2002    43619    52448  ...    18956    86942     1369    39466    22420
# 2003    43462    52513  ...    18859    87333     1346    40699    22444
# 2004    43349    52311  ...    18858    87018     1315    41766    22483
# 2005    43175    52328  ...    19064    87088     1245    42653    22993
# 2006    43119    52482  ...    19236    87291     1184    43831    23746
# 2007    43465    53053  ...    19437    89631     1196    45388    24231
# 2008    43837    53725  ...    19804    91064     1207    46572    24406
# 2009    44438    54493  ...    20232    92757     1388    47712    24664
# 2010    44927    55353  ...    20424    95023     1477    48739    24925
# 2011    45360    56318  ...    20400    95649     1549    49910    25176
#
#       80107.0  80108.0  80109.0  80104.0  90101.0
# 1991    74412    27118    33921      NaN      NaN
# 1992    81051    26663    33967      NaN      NaN
# 1993    85293    26038    33666   3755.0      NaN
# 1994    87886    25557    33311   6746.0   1501.0
# 1995    89386    25047    33202  10233.0   1644.0
# 1996    90507    24874    33192  12741.0   1832.0
# 1997    90439    24472    32827  15234.0   1675.0
# 1998    90387    24090    32673  17344.0   1607.0
# 1999    90620    23969    32644  19807.0   1545.0
# 2000    91058    23749    32627  21860.0   1472.0
# 2001    91507    23726    32719  24568.0   1442.0
# 2002    91299    23657    32861  26104.0   1365.0
# 2003    91176    23004    32962  27916.0   1337.0
# 2004    90558    22705    32832  29802.0   1355.0
# 2005    90227    22710    33013  31029.0   1380.0
# 2006    90030    22694    33226  32750.0   1403.0
# 2007    90465    22927    33409  34972.0   1569.0
# 2008    90525    23056    33570  37534.0   1745.0
# 2009    90748    23230    33815  40004.0   1944.0
# 2010    90481    23421    34068  43101.0   2115.0
# 2011    89319    23354    34124  48337.0   2167.0
#
# [21 rows x 327 columns]

# %%
def split_sequence(sequence, n_steps):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the sequence
		if end_ix > len(sequence)-1:
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

# %%
# define input sequence
sample_data = list(population_per_year_dict[10101.0].values())
# choose a number of time steps
n_steps = 5
# split into samples
X, y = split_sequence(sample_data, n_steps)
# summarize the data
for i in range(len(X)):
	print(X[i], y[i])
# Out:
# [61667 61751 61706 61651 61602] 61786
# [61751 61706 61651 61602 61786] 61968
# [61706 61651 61602 61786 61968] 62283
# [61651 61602 61786 61968 62283] 62576
# [61602 61786 61968 62283 62576] 62952
# [61786 61968 62283 62576 62952] 63370
# [61968 62283 62576 62952 63370] 63784
# [62283 62576 62952 63370 63784] 64245
# [62576 62952 63370 63784 64245] 64550
# [62952 63370 63784 64245 64550] 64891
# [63370 63784 64245 64550 64891] 65284
# [63784 64245 64550 64891 65284] 65807
# [64245 64550 64891 65284 65807] 66670
# [64550 64891 65284 65807 66670] 67745
# [64891 65284 65807 66670 67745] 68950
# [65284 65807 66670 67745 68950] 69775

# %%
# train data
train_x = X[:6]
train_y = y[:6]
# validation data
val_x = X[6:10]
val_y = y[6:10]
# test data
test_x = X[10:]
test_y = y[10:]

# %%
# univariate lstm example
from numpy import array
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense

# %%
# reshape from [samples, timesteps] into [samples, timesteps, features]
n_features = 1
train_x = train_x.reshape((train_x.shape[0], train_x.shape[1], n_features))
# define model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# fit model
model.fit(train_x, train_y, epochs=200, verbose=0)

# demonstrate prediction
x_input = val_x
for i in range(len(x_input)):
    val_x = x_input[i].reshape((1, n_steps, n_features))
    yhat = model.predict(val_x, verbose=0)
    print(yhat)
# Out:
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2022-07-09 14:13:30.535132: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# [[63148.94]]
# [[63507.652]]
# [[63890.605]]
# [[64290.35]]
# 2022-07-09 14:13:37.412380: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
val_y
# Out:
# array([63784, 64245, 64550, 64891])
